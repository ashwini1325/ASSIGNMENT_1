# %%
a = "ashu"

# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
# +
# 6

# %% [markdown]
# ANS: 'hello', -87.8, 6 these are the values.(because these are the integer, string and floating point)
#     *, -, /, + these are the expression.(because these are the mathematical operators)

# %% [markdown]
# 2.What is the difference between string and variable?

# %% [markdown]
# ANS: A variable is any characteristics, number, or quantity that can be measured or counted.
#     A variable may also be called a data item. Age, sex, business income and expenses, country of birth,
#     capital expenditure, class grades, eye colour and vehicle type are examples of variables.
#     and a String is a type of information you would store in a Variable.
#     A String is usually words, enclosed with "" Eg String x ="Welcome to PYTHON WORLD" X is the Variable,
#     and we declared it as a String, use the single = to assign the text to it.

# %% [markdown]
# 3. Describe three different data types.

# %% [markdown]
# ANS: INTEGER(int), STRING(str), FLOATING POINT(float), BOOLEAN(bool) etc..

# %% [markdown]
# 4. What is an expression made up of? What do all expressions do?

# %% [markdown]
# ANS: AN EXPRESSION IS A COMBINATION OF OPERATORS AND OPERANDS THAT IS INTERPRETED TO PREDUCE SOME OTHER VALUE.
#     FOR EXAMPLE, THIS IS AN EXPRESSION: >>> 4 + 4. THE 4s ARE INTEGER VALUES AND THE + IS THE MATHEMATICAL OPERATOR.
#     THIS EXPRESSION EVALUATES DOWN TO THE SINGLE INTEGER VALUE 8.

# %% [markdown]
# 5. This assignment statements, like spam = 10. What is the difference between an
# expression and a statement?

# %% [markdown]
# ANS: EXPRESSION IS MADE UP OF VALUES, CONTAINER, AND MATHEMATICAL OPERATORS OR (OPERANDS)
#     AND THE STATEMENT IS JUST LIKE A COMMAND THAT A PYTHON INTERPRETER EXECUTES LIKE PRINT.
#     EXAMPLE:"8+9" IS AN EXPRESSION, BUT "FOO = 8+9" IS NOT. IF IT DOES'T WORK, IT'S A STATEMENT, IF IT DOES, IF IT DOES,
#     IT'S AN EXPRESSION. AS IT CANNOT BE REDUCED TO A VALUE.

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1

# %% [markdown]
# ANS: 23

# %% [markdown]
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam'* 3

# %% [markdown]
# ANS: 'spamspamspam'

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# ANS= 'VARIABLE NAMES CANNOT BEGIN WITH A NUMBER'. HENCE 100 IS A INVALID.

# %% [markdown]
# 9. What three functions can be used to get the integer, floating-point number, or string
# version of a value?

# %% [markdown]
# ANS: The int() , float() , and str( ) functions will evaluate to the integer, floating-point number, and
#     string versions of the value passed to them.

# %% [markdown]
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten' + 99 +  'burritos'.

# %% [markdown]
# ANS:"THE EXPRESSION CAUSES AN ERROR BECAUSE 99 IS AN INTEGER, AND ONLY STRINGS CAN BE CONCATENATED TO OTHER STRINGS WITH THE + OPERATOR.
# THE CORRECT WAY IS I HAVE EATEN ' + STR(99) + ' BURRITOS"

# %%
 'I have eaten ' + str(99) + ' burritos.'
# Out:
# 'I have eaten 99 burritos.'
